# %%
import pandas as pd
from pmdarima import auto_arima
from prophet import Prophet
import matplotlib.pyplot as plt

# %%
df = pd.read_parquet("../../data/processed/volume_clean.parquet")

# %%
train = pd.read_parquet('../../data/processed/volume/train.parquet')
test = pd.read_parquet('../../data/processed/volume/test.parquet')
test.head(3)
# Out:
#          date  cheese  milk  dulce_leche  eggs  porks  vegetables
# 48 2024-01-01      40   790           12    12      5          40
# 49 2024-02-01      45   810           10    13      6          42
# 50 2024-03-01      50   830           13    14      6          45

# %%
X_train = train.drop(columns=["date", "milk"])
X_test = test.drop(columns=["date", "milk"])
y_test = test["milk"]
y_train = train["milk"]

# %%
model = auto_arima(y_train, seasonal=True, m=12)

n_periods = len(y_test)
forecast = model.predict(n_periods=n_periods, X=X_test)
forecast = pd.Series(forecast, index=y_test.index)
forecast
# Out:
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 48    755.100929
# 49    755.100929
# 50    755.100929
# 51    755.100929
# 52    755.100929
# 53    755.100929
# 54    755.100929
# 55    755.100929
# 56    755.100929
# 57    755.100929
# 58    755.100929
# 59    755.100929
# dtype: float64

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_train, label="Train")
plt.plot(y_test, label="Test")
plt.plot(forecast, label="Forecast", linestyle="--")
plt.legend()
plt.title("Auto ARIMA com Regressor Exógeno")
plt.grid(True)
plt.show()

# %%
df_prophet_milk = df.reset_index()[['date', 'milk']].rename(columns={
    'date': 'ds',
    'milk': 'y'
})
model_prophet_milk = Prophet()
model_prophet_milk.fit(df_prophet_milk)
# Out:
# 10:46:24 - cmdstanpy - INFO - Chain [1] start processing
# 10:46:24 - cmdstanpy - INFO - Chain [1] done processing

# %%
df_prophet_cheese = df.reset_index()[['date', 'cheese']].rename(columns={
    'date': 'ds',
    'cheese': 'y'
})
model_prophet_cheese = Prophet()
model_prophet_cheese.fit(df_prophet_cheese)
# Out:
# 10:46:33 - cmdstanpy - INFO - Chain [1] start processing
# 10:46:33 - cmdstanpy - INFO - Chain [1] done processing

# %%
df_prophet_porks = df.reset_index()[['date', 'porks']].rename(columns={
    'date': 'ds',
    'porks': 'y'
})
model_prophet_porks = Prophet()
model_prophet_porks.fit(df_prophet_porks)
# Out:
# 10:46:42 - cmdstanpy - INFO - Chain [1] start processing
# 10:46:42 - cmdstanpy - INFO - Chain [1] done processing

# %%
future_milk = model_prophet_milk.make_future_dataframe(periods=12, freq='M')
forecast_milk = model_prophet_milk.predict(future_milk)

future_cheese = model_prophet_cheese.make_future_dataframe(periods=12, freq='M')
forecast_cheese = model_prophet_cheese.predict(future_cheese)

future_porks = model_prophet_porks.make_future_dataframe(periods=12, freq='M')
forecast_porks = model_prophet_porks.predict(future_porks)
# Out:
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/prophet/forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/prophet/forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# /home/guilherme/Documentos/Cooperativa/venv/lib/python3.13/site-packages/prophet/forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(

# %%
model_prophet_milk.plot(forecast_milk)
plt.title('Prophet - Milk Revenue')
plt.grid(True)
plt.show()

model_prophet_milk.plot_components(forecast_milk)
plt.tight_layout()
plt.show()

# %%
model_prophet_cheese.plot(forecast_cheese)
plt.title('Prophet - Milk Revenue')
plt.grid(True)
plt.show()

model_prophet_cheese.plot_components(forecast_cheese)
plt.tight_layout()
plt.show()

# %%
model_prophet_porks.plot(forecast_porks)
plt.title('Prophet - Milk Revenue')
plt.grid(True)
plt.show()

model_prophet_porks.plot_components(forecast_porks)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error
df['date'] = pd.to_datetime(df['date'])
forecast_milk['ds'] = pd.to_datetime(forecast_milk['ds'])

df_eval = pd.merge(
    df[['date', 'milk']],
    forecast_milk[['ds', 'yhat']],
    left_on='date',
    right_on='ds',
    how='inner'
)
y_true = df_eval['milk']
y_pred = df_eval['yhat']

# Verifique os shapes
print(f"Shape y_true: {y_true.shape}, y_pred: {y_pred.shape}")

# Calcule MAE
if len(y_true) == len(y_pred):
    print(f"MAE: {mean_absolute_error(y_true, y_pred):.2f}")
else:
    print("Erro: y_true e y_pred têm tamanhos diferentes.")
# Out:
# Shape y_true: (60,), y_pred: (60,)
# MAE: 136.97
